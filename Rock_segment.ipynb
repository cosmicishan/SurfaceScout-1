# %%
from ultralytics import YOLO

model = YOLO("best.pt")

# %%
results = model.predict("/home/ishan/Projects/Flask/rock.jpg")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 results = model.predict("/home/ishan/Projects/Flask/rock.jpg")
#
# File ~/anaconda3/envs/computervision/lib/python3.9/site-packages/ultralytics/engine/model.py:239, in Model.predict(self, source, stream, predictor, **kwargs)
#     237 if prompts and hasattr(self.predictor, 'set_prompts'):  # for SAM-type models
#     238     self.predictor.set_prompts(prompts)
# --> 239 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/anaconda3/envs/computervision/lib/python3.9/site-packages/ultralytics/engine/predictor.py:198, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     196     return self.stream_inference(source, model, *args, **kwargs)
#     197 else:
# ...
